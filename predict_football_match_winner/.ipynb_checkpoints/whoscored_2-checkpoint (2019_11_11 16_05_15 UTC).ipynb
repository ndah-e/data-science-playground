# %%
import pandas as pd 
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

from sklearn.metrics import roc_auc_score
from sklearn.feature_selection import SelectFromModel


# use feature importance for feature selection
from numpy import loadtxt
from numpy import sort
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectFromModel

# hidden neuron selection
# one could get decent performance by setting the hidden layer configuration using just two rules: 
#(i) number of hidden layers equals one; and 
#(ii) the number of neurons in that layer is the mean of the neurons in the input and output layers.

# %%
df = pd.read_csv('data/FootballEurope.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (38,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#df.head()
#df.columns
df.division.unique()
#['EPL', 'Bundesliga', 'Ligue_1', 'La_Liga', 'Serie_A']
# Out:
# array(['EPL', 'Bundesliga', 'Ligue_1', 'La_Liga', 'Serie_A'], dtype=object)

# %%
#df.loc[df.homeGoalFT - df.awayGoalFT > 0, 'FTR'] = 'H' 
#df.loc[df.homeGoalFT - df.awayGoalFT == 0, 'FTR'] = 'D' 
#df.loc[df.homeGoalFT - df.awayGoalFT < 0, 'FTR'] = 'A'

df.loc[df.homeGoalFT - df.awayGoalFT > 0, 'FTR'] = 0
df.loc[df.homeGoalFT - df.awayGoalFT == 0, 'FTR'] = 1 
df.loc[df.homeGoalFT - df.awayGoalFT < 0, 'FTR'] = 2

df['FTG'] = df.homeGoalFT + df.awayGoalFT

# %%
results = ['homeGoalHT','awayGoalHT','homeGoalFT','awayGoalFT','FTR','FTG']
numeric_cols = df.select_dtypes([np.number]).columns

# %%
cols_to_drop = ['id','homeTeamLineUp', 'awayTeamLineUp', 'homeFormation', 'awayFormation','awayManagerName','homeManagerName', 
                'venueName','date', 'division', 'FTR', 'FTG','awayGoalHT', 'homeGoalHT','homeGoalFT', 'awayGoalFT', 
                'division', 'homeTeam', 'awayTeam', 'refereeName']

# %%
from scipy.stats import kruskal

def kruskal_walllis_asso(df,variables):
    tmp_H = df[df.FTR == 'H']
    tmp_D = df[df.FTR == 'D']
    tmp_A = df[df.FTR == 'A']

    pvalues = []

    for var in variables:
        stat, p = kruskal(tmp_H[var], tmp_D[var], tmp_A[var])
        print('Statistics=%.3f, p=%.3f' % (stat, p))

        pvalues.append(p)
        alpha = 0.05
        if p > alpha:
            print('No statistically significant difference between groups for ' + var)

        print()
        
        return pvalues

#feature_pvalues = pd.DataFrame({'feature':variables,'pvalue':pvalues}).sort_values(by='pvalue')

#f, ax = plt.subplots(figsize=(12, 12))
#sns.barplot(x="pvalue", y="feature", data=feature_pvalues)
#plt.title('Features p values')

# %%
#from scipy.stats.stats import pearsonr 
#for var in variables:
#    print("Correlation with " + var)
#    print(pearsonr(df["FTG"],df[var])[0])
#    print()

# %%
HT_cols = [col for col in df.columns if col[-2:] == 'HT']

data = df
#['EPL', 'Bundesliga', 'Ligue_1', 'La_Liga', 'Serie_A']
#data = df[df.division == 'Ligue_1']

# %% [markdown]
# ### Feature engineering

# %%
HT_cols = [col for col in df.columns if col[-2:] == 'HT']
cols_to_drop = cols_to_drop + HT_cols

variable = data.drop(cols_to_drop, axis=1)

# %%
from string import ascii_letters

#corr = df[variables]).corr()

cols_to_drop = cols_to_drop + HT_cols
corr = data.drop(cols_to_drop, axis=1)
corr = corr.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(12, 12))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
import pandas as pd
import numpy as np


corr = data.drop(cols_to_drop, axis=1)
def get_corrs(df):
    col_correlations = df.corr()
    col_correlations.loc[:, :] = np.tril(col_correlations, k=-1)
    cor_pairs = col_correlations.stack()
    
    return cor_pairs.to_dict()

my_corrs = get_corrs(corr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-96e61a660a35> in <module>()
#       3
#       4
# ----> 5 corr = data.drop(cols_to_drop, axis=1)
#       6 def get_corrs(df):
#       7     col_correlations = df.corr()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
#    2564             try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3742             if errors != 'ignore':
#    3743                 raise ValueError('labels %s not contained in axis' %
# -> 3744                                  labels[mask])
#    3745             indexer = indexer[~mask]
#    3746         return self.delete(indexer)
#
# ValueError: labels ['awayGoalHT' 'homeGoalHT' 'homeTacklesTotalHT' 'homeShotsTotalHT'
#  'awayDribblesAttemptedHT' 'awayShotsBlockedHT' 'awayShotsTotalHT'
#  'homeDribbleSuccessHT' 'homeRatingsHT' 'homeInterceptionsHT'
#  'awayPossessionHT' 'awayShotsOnTargetHT' 'awayTackleSuccessHT'
#  'homeAerialsTotalHT' 'awayCornersTotalHT' 'homeCornersTotalHT'
#  'awayPassSuccessHT' 'awayDribblesWonHT' 'homeDispossessedHT'
#  'homeShotsBlockedHT' 'homeTackleSuccessHT' 'awayPassesKeyHT'
#  'awayInterceptionsHT' 'awayDispossessedHT' 'homeDribblesWonHT'
#  'awayAerialsTotalHT' 'awayGoalHT' 'homeGoalHT' 'awayDribbleSuccessHT'
#  'awayTacklesTotalHT' 'homeShotsOnTargetHT' 'awayOffsidesCaughtHT'
#  'homeDribbledPastHT' 'awayFoulsCommitedHT' 'homeFoulsCommitedHT'
#  'homeDribblesAttemptedHT' 'awayRatingsHT' 'homeOffsidesCaughtHT'
#  'awayDribbledPastHT' 'homePassesKeyHT' 'homePossessionHT'
#  'homePassSuccessHT' 'homeTacklesTotalHT' 'homeShotsTotalHT'
#  'awayDribblesAttemptedHT' 'awayShotsBlockedHT' 'awayShotsTotalHT'
#  'homeDribbleSuccessHT' 'homeRatingsHT' 'homeInterceptionsHT'
#  'awayPossessionHT' 'awayShotsOnTargetHT' 'awayTackleSuccessHT'
#  'homeAerialsTotalHT' 'awayCornersTotalHT' 'homeCornersTotalHT'
#  'awayPassSuccessHT' 'awayDribblesWonHT' 'homeDispossessedHT'
#  'homeShotsBlockedHT' 'homeTackleSuccessHT' 'awayPassesKeyHT'
#  'awayInterceptionsHT' 'awayDispossessedHT' 'homeDribblesWonHT'
#  'awayAerialsTotalHT' 'awayGoalHT' 'homeGoalHT' 'awayDribbleSuccessHT'
#  'awayTacklesTotalHT' 'homeShotsOnTargetHT' 'awayOffsidesCaughtHT'
#  'homeDribbledPastHT' 'awayFoulsCommitedHT' 'homeFoulsCommitedHT'
#  'homeDribblesAttemptedHT' 'awayRatingsHT' 'homeOffsidesCaughtHT'
#  'awayDribbledPastHT' 'homePassesKeyHT' 'homePossessionHT'
#  'homePassSuccessHT'] not contained in axis

# %%
from sklearn.model_selection import train_test_split

#HT_cols = [col for col in data.columns if col[-2:] == 'HT']
#cols_to_drop = cols_to_drop + HT_cols

data = data.dropna()

FTR = data.FTR
x_train, x_test, y_train, y_test = train_test_split(data.drop(cols_to_drop, axis=1), FTR, train_size=0.90, 
                                                    test_size=0.1, random_state=12)

# %%
#x_train = x_train.drop(cols_to_drop, axis=1)
#x_train = x_train.drop(cols_to_drop, axis=1)

data = data.drop(HT_cols, axis = 1)

#x_train.columns

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(oob_score=True, random_state=12)
rf.fit(x_train, y_train)

print(rf.oob_score_)
# Out:
# 0.5817589576547231
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])

# %%
from sklearn.metrics import accuracy_score

pred = rf.predict(x_test)
#pred = rf.predict(x_test.drop(cols_to_drop, axis=1))

print(pd.crosstab(y_test, pred))
accuracy_score(y_test, pred)
# Out:
# col_0  0.0  1.0  2.0
# FTR
# 0.0     55   14    1
# 1.0     22   13   11
# 2.0      2   19   34
# 0.5964912280701754

# %%
feature_importance = pd.DataFrame({'feature':x_train.columns,
                                   'importance':rf.feature_importances_}).sort_values(by='importance', ascending=False)

f, ax = plt.subplots(figsize=(12, 12))
sns.barplot(x="importance", y="feature", data=feature_importance.head(25))
plt.title('Features Importance')
# Out:
# Text(0.5,1,'Features Importance')

# %%
# fit model on all training data
rf.fit(x_train, y_train)

# make predictions for test data and evaluate
y_pred = rf.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

# Fit model using each importance as a threshold
number_of_var = 2
best_threshold = 0
default_accuracy = accuracy
thresholds = sort(rf.feature_importances_)
for thresh in thresholds:
    
    # select features using threshold
    selection = SelectFromModel(rf, threshold=thresh, prefit=True)
    select_X_train = selection.transform(x_train)
    
    # train model
    selection_model = RandomForestClassifier(random_state=12)
    selection_model.fit(select_X_train, y_train)
    
    # eval model
    select_X_test = selection.transform(x_test)
    y_pred = selection_model.predict(select_X_test)
    accuracy = accuracy_score(y_test, y_pred)
    
    print("Thresh=%.3f, n=%d, Accuracy: %.2f%%" % (thresh, select_X_train.shape[1], accuracy*100.0))
    
    if default_accuracy < accuracy:
        default_accuracy = accuracy
        best_threshold = thresh
        number_of_var = select_X_train.shape[1]

best_threshold = round(best_threshold,4)
print()
print("Best results: ")
print("Thresh=%.3f, n=%d, Accuracy: %.2f%%" % (best_threshold, number_of_var, default_accuracy*100.0))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# Accuracy: 59.65%
# Thresh=0.009, n=38, Accuracy: 59.65%
# Thresh=0.012, n=37, Accuracy: 59.06%
# Thresh=0.012, n=36, Accuracy: 62.57%
# Thresh=0.014, n=35, Accuracy: 67.84%
# Thresh=0.015, n=34, Accuracy: 60.23%
# Thresh=0.015, n=33, Accuracy: 62.57%
# Thresh=0.015, n=32, Accuracy: 59.65%
# Thresh=0.015, n=31, Accuracy: 60.23%
# Thresh=0.015, n=30, Accuracy: 64.91%
# Thresh=0.016, n=29, Accuracy: 69.01%
# Thresh=0.017, n=28, Accuracy: 67.25%
# Thresh=0.018, n=27, Accuracy: 66.08%
# Thresh=0.018, n=26, Accuracy: 64.91%
# Thresh=0.018, n=25, Accuracy: 67.25%
# Thresh=0.019, n=24, Accuracy: 68.42%
# Thresh=0.019, n=23, Accuracy: 66.08%
# Thresh=0.019, n=22, Accuracy: 64.33%
# Thresh=0.019, n=21, Accuracy: 66.08%
# Thresh=0.019, n=20, Accuracy: 60.23%
# Thresh=0.019, n=19, Accuracy: 69.01%
# Thresh=0.019, n=18, Accuracy: 69.59%
# Thresh=0.019, n=17, Accuracy: 64.91%
# Thresh=0.020, n=16, Accuracy: 70.76%
# Thresh=0.020, n=15, Accuracy: 67.84%
# Thresh=0.020, n=14, Accuracy: 66.08%
# Thresh=0.022, n=13, Accuracy: 69.01%
# Thresh=0.022, n=12, Accuracy: 67.25%
# Thresh=0.022, n=11, Accuracy: 71.35%
# Thresh=0.023, n=10, Accuracy: 67.84%
# Thresh=0.023, n=9, Accuracy: 69.01%
# Thresh=0.023, n=8, Accuracy: 67.84%
# Thresh=0.024, n=7, Accuracy: 69.59%
# Thresh=0.025, n=6, Accuracy: 65.50%
# Thresh=0.031, n=5, Accuracy: 63.16%
# Thresh=0.038, n=4, Accuracy: 66.08%
# Thresh=0.055, n=3, Accuracy: 61.40%
# Thresh=0.130, n=2, Accuracy: 64.91%
# Thresh=0.141, n=1, Accuracy: 61.40%
#
# Best results:
# Thresh=0.022, n=11, Accuracy: 71.35%

# %%
# best subset of features
print(best_threshold)
best_feat = feature_importance[feature_importance.importance >= best_threshold]
print(best_feat)
# Out:
# 0.0222
#                  feature  importance
# 2          awayRatingsFT    0.141268
# 33         homeRatingsFT    0.129525
# 6    awayShotsOnTargetFT    0.055052
# 27   homeShotsOnTargetFT    0.038118
# 1      awayPassSuccessFT    0.031170
# 36      awayPossessionFT    0.025149
# 24     homePassSuccessFT    0.023872
# 15      homePossessionFT    0.023479
# 12  homeDribbleSuccessFT    0.023434
# 16   awayInterceptionsFT    0.023354
# 23      homeShotsTotalFT    0.022239

# %%
rf_model = RandomForestClassifier(random_state=12)
rf_model.fit(x_train[best_feat.feature], y_train)

pred = rf_model.predict(x_test[best_feat.feature])
print(pd.crosstab(y_test, pred))
accuracy_score(y_test, pred)
# Out:
# col_0  0.0  1.0  2.0
# FTR
# 0.0     59    9    2
# 1.0     14   22   10
# 2.0      6   12   37
# 0.6900584795321637

# %%
from sklearn.grid_search import GridSearchCV

rfc = RandomForestClassifier(max_features='sqrt', oob_score = True) 

# Use a grid over parameters of interest
param_grid = { 
           "n_estimators" : [18, 27, 36, 45, 54, 63, 79, 86, 95, 100, 120],
           "max_depth" : [1, 5, 10, 15, 20, 25, 30, 35],
           "min_samples_leaf" : [1, 2, 4, 6, 8, 10]}

#CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 10)
#CV_rfc.fit(x_train, y_train)
#print(CV_rfc.best_params_)

# %%
stop

# %% [markdown]
# ### XGBoost

# %%
import xgboost as xgb
from xgboost import plot_importance

gbm = xgb.XGBClassifier().fit(x_train, y_train)

# %%
feature_xgb_importances = pd.DataFrame({'feature':x_train.columns,
                                   'Importance':gbm.feature_importances_}).sort_values(by='Importance', ascending=False)

f, ax = plt.subplots(figsize=(12, 12))
sns.barplot(x="Importance", y="feature", data=feature_xgb_importances.head(30))
plt.title('xgboost Importance')
# Out:
# Text(0.5,1,'xgboost Importance')

# %%
pred_prob = gbm.predict(x_test)
pred = np.asarray([np.argmax(line) for line in pred_prob])

print(pd.crosstab(y_test, pred))
accuracy_score(y_test, pred)
#roc_auc_score(y_test, pred)
# Out:
# col_0   0
# FTR
# 0.0    67
# 1.0    52
# 2.0    53
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 0.38953488372093026

# %%
# fit model on all training data
model = XGBClassifier()
model.fit(x_train, y_train)

# make predictions for test data and evaluate
y_pred = model.predict(x_test)
predictions = [round(value) for value in y_pred]
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

# Fit model using each importance as a threshold
thresholds = sort(model.feature_importances_)
for thresh in thresholds:
    # select features using threshold
    selection = SelectFromModel(model, threshold=thresh, prefit=True)
    select_X_train = selection.transform(x_train)
    # train model
    selection_model = XGBClassifier()
    selection_model.fit(select_X_train, y_train)
    # eval model
    select_X_test = selection.transform(x_test)
    y_pred = selection_model.predict(select_X_test)
    predictions = [round(value) for value in y_pred]
    accuracy = accuracy_score(y_test, predictions)
    print("Thresh=%.3f, n=%d, Accuracy: %.2f%%" % (thresh, select_X_train.shape[1], accuracy*100.0))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Accuracy: 64.53%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.000, n=38, Accuracy: 64.53%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.000, n=38, Accuracy: 64.53%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.002, n=36, Accuracy: 64.53%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.005, n=35, Accuracy: 65.12%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.005, n=35, Accuracy: 65.12%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.005, n=33, Accuracy: 66.28%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.009, n=32, Accuracy: 66.28%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.010, n=31, Accuracy: 67.44%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.011, n=30, Accuracy: 66.28%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.011, n=30, Accuracy: 66.28%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.011, n=28, Accuracy: 67.44%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.013, n=27, Accuracy: 68.60%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.014, n=26, Accuracy: 66.28%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.014, n=25, Accuracy: 66.28%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.015, n=24, Accuracy: 64.53%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.016, n=23, Accuracy: 67.44%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.017, n=22, Accuracy: 66.28%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.017, n=21, Accuracy: 66.28%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.018, n=20, Accuracy: 63.95%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.019, n=19, Accuracy: 67.44%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.019, n=18, Accuracy: 66.86%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.021, n=17, Accuracy: 66.28%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.022, n=16, Accuracy: 66.28%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.022, n=16, Accuracy: 66.28%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.025, n=14, Accuracy: 66.28%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.026, n=13, Accuracy: 66.28%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.026, n=13, Accuracy: 66.28%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.030, n=11, Accuracy: 69.77%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.031, n=10, Accuracy: 67.44%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.033, n=9, Accuracy: 68.60%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.036, n=8, Accuracy: 68.60%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.038, n=7, Accuracy: 67.44%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.040, n=6, Accuracy: 65.70%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.050, n=5, Accuracy: 68.02%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.059, n=4, Accuracy: 68.02%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Thresh=0.066, n=3, Accuracy: 66.86%
# Thresh=0.122, n=2, Accuracy: 67.44%
# Thresh=0.124, n=1, Accuracy: 65.12%
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %% [markdown]
# #### Univariate prediction peroformance

# %%
#oob_error = []
#for var in x_train.columns:
#    df_tmp = x_train[var]
#    df_tmp = df_tmp.values.reshape(-1, 1)
#    rf.fit(df_tmp, y_train)
#    oob_error.append(rf.oob_score_)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])

# %%
#feature_accuracy = pd.DataFrame({'feature':x_train.columns,
#                                   'Accuracy':oob_error}).sort_values(by='Accuracy', ascending=False)
#f, ax = plt.subplots(figsize=(12, 12))
#sns.barplot(x="Accuracy", y="feature", data=feature_accuracy.head(30))
#plt.title('Features Univariate accuracy')
# Out:
# Text(0.5,1,'Features Univariate accuracy')

# %%
# best subset of features
#best_feat = feature_accuracy[feature_accuracy.Accuracy >= 0.46]
#best_feat = feature_accuracy.head(11)
#print(len(best_feat))
#print(best_feat)
# Out:
# 10
#     Accuracy              feature
# 2   0.667098        awayRatingsFT
# 33  0.655462        homeRatingsFT
# 6   0.535229  awayShotsOnTargetFT
# 27  0.518423  homeShotsOnTargetFT
# 37  0.482224     awayShotsTotalFT
# 14  0.477052      awayPassesKeyFT
# 23  0.464771     homeShotsTotalFT
# 8   0.464771      homePassesKeyFT
# 18  0.460892    homeDribblesWonFT
# 22  0.460892   awayDribbledPastFT

# %%
#rf.fit(x_train[best_feat.feature], y_train)
#pred = rf.predict(x_train[best_feat.feature])
#print(rf.oob_score_)
#print(accuracy_score(y_train, pred))
# Out:
# 0.6263736263736264
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:453: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:458: RuntimeWarning: invalid value encountered in true_divide
#   predictions[k].sum(axis=1)[:, np.newaxis])

# %%
#pred = rf.predict(x_test[best_feat.feature])
#print(pd.crosstab(y_test, pred))
#accuracy_score(y_test, pred)
# Out:
# col_0  0.0  1.0  2.0
# FTR
# 0.0     56    9    2
# 1.0     15   22   15
# 2.0      4   15   34
# 0.6511627906976745

# %% [markdown]
# ### TPOT

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-4f76a9dad686> in <module>()
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
from tpot import TPOTClassifier

tpot = TPOTClassifier(generations=5, population_size=5, verbosity=3)
tpot.fit(x_train, y_train)
print(tpot.score(x_test, y_test))
tpot.export('tpot_pipeline.py')
